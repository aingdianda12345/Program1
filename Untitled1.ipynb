# %%
list_kosong = []

# %%
list_buah=["Pisang", "Nanas", "Melon", "Durian"]

# %%
list_angka=[345,666,978,888]

# %%
list_campur=["ayam",2543,"pisang",6354]

# %%
print('list kosong',list_kosong)
# Out:
# list kosong []

# %%
print('list buah',list_buah)
# Out:
# list buah ['Pisang', 'Nanas', 'Melon', 'Durian']

# %%
print('list angka',list_angka)
# Out:
# list angka [345, 666, 978, 888]

# %%
print(list_buah)
# Out:
# ['Pisang', 'Nanas', 'Melon', 'Durian']

# %%
print(list_buah[0])
# Out:
# Pisang

# %%
print(list_buah[1])
# Out:
# Nanas

# %%
print(list_buah[2])
# Out:
# Melon

# %%
print(list_buah[3])
# Out:
# Durian
